# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
pre_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Metric"
url = f"{pre_url}units={units}&APPID={weather_api_key}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | paranaiba
# Processing Record 2 of Set 1 | afaahiti
# Processing Record 3 of Set 1 | enewetak
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | saipan
# Processing Record 6 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | sinabang
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | olonkinbyen
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | bilibino
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | ormara
# Processing Record 15 of Set 1 | sinjar
# Processing Record 16 of Set 1 | korem
# Processing Record 17 of Set 1 | waingapu
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | constantia
# Processing Record 20 of Set 1 | waitangi
# Processing Record 21 of Set 1 | nacala
# Processing Record 22 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | kone
# Processing Record 25 of Set 1 | zeya
# Processing Record 26 of Set 1 | ad dabbah
# Processing Record 27 of Set 1 | barcelos
# Processing Record 28 of Set 1 | khandyga
# Processing Record 29 of Set 1 | hawaiian paradise park
# Processing Record 30 of Set 1 | batesburg-leesville
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | cabedelo
# Processing Record 33 of Set 1 | aykhal
# Processing Record 34 of Set 1 | utrik
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | mcgregor
# Processing Record 37 of Set 1 | newman
# Processing Record 38 of Set 1 | sao vicente
# Processing Record 39 of Set 1 | udachny
# Processing Record 40 of Set 1 | khemisset
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | alofi
# Processing Record 43 of Set 1 | blackmans bay
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | ciudad lazaro cardenas
# Processing Record 46 of Set 1 | iskateley
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | vorgashor
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | dudinka
# Processing Record 0 of Set 2 | laojunmiao
# Processing Record 1 of Set 2 | bemidji
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | klyuchi
# Processing Record 5 of Set 2 | hammerfest
# Processing Record 6 of Set 2 | edinburgh of the seven seas
# Processing Record 7 of Set 2 | konarka
# Processing Record 8 of Set 2 | ciudad guayana
# Processing Record 9 of Set 2 | kapa'a
# Processing Record 10 of Set 2 | kajaani
# Processing Record 11 of Set 2 | tazacorte
# Processing Record 12 of Set 2 | haiku-pauwela
# Processing Record 13 of Set 2 | glace bay
# Processing Record 14 of Set 2 | peace river
# Processing Record 15 of Set 2 | uturoa
# Processing Record 16 of Set 2 | laguna
# Processing Record 17 of Set 2 | port mathurin
# Processing Record 18 of Set 2 | olofstrom
# City not found. Skipping...
# Processing Record 19 of Set 2 | otjimbingwe
# Processing Record 20 of Set 2 | mao
# Processing Record 21 of Set 2 | remire-montjoly
# Processing Record 22 of Set 2 | san andros
# City not found. Skipping...
# Processing Record 23 of Set 2 | raja
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | malango
# Processing Record 26 of Set 2 | kristiansund
# Processing Record 27 of Set 2 | queenstown
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | tolanaro
# Processing Record 30 of Set 2 | margaret river
# Processing Record 31 of Set 2 | macapa
# Processing Record 32 of Set 2 | freetown
# Processing Record 33 of Set 2 | west island
# Processing Record 34 of Set 2 | kakunodatemachi
# Processing Record 35 of Set 2 | st. john's
# Processing Record 36 of Set 2 | buchanan
# Processing Record 37 of Set 2 | conception bay south
# Processing Record 38 of Set 2 | bardai
# Processing Record 39 of Set 2 | hudiksvall
# Processing Record 40 of Set 2 | fale old settlement
# Processing Record 41 of Set 2 | nova sintra
# Processing Record 42 of Set 2 | taggia
# Processing Record 43 of Set 2 | sylvan lake
# Processing Record 44 of Set 2 | tamanrasset
# Processing Record 45 of Set 2 | saint-pierre
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | grytviken
# Processing Record 48 of Set 2 | san juan de miraflores
# Processing Record 49 of Set 2 | flying fish cove
# Processing Record 0 of Set 3 | urangan
# Processing Record 1 of Set 3 | arkhangel'sk
# Processing Record 2 of Set 3 | puerto natales
# Processing Record 3 of Set 3 | bei'an
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | lensk
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | tarariras
# Processing Record 9 of Set 3 | nguigmi
# Processing Record 10 of Set 3 | badger
# Processing Record 11 of Set 3 | khorixas
# Processing Record 12 of Set 3 | santa terezinha
# Processing Record 13 of Set 3 | albany
# Processing Record 14 of Set 3 | conde
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | berbera
# Processing Record 17 of Set 3 | nioki
# Processing Record 18 of Set 3 | invercargill
# Processing Record 19 of Set 3 | tual
# Processing Record 20 of Set 3 | papatowai
# Processing Record 21 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 3 | vilyuysk
# Processing Record 23 of Set 3 | verkhneyarkeyevo
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | aanekoski
# Processing Record 26 of Set 3 | lata
# Processing Record 27 of Set 3 | isla mujeres
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | champerico
# Processing Record 30 of Set 3 | villa gesell
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | bumba
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | kirakira
# Processing Record 35 of Set 3 | susuman
# Processing Record 36 of Set 3 | weno
# Processing Record 37 of Set 3 | segarcea
# Processing Record 38 of Set 3 | alzamay
# Processing Record 39 of Set 3 | menongue
# Processing Record 40 of Set 3 | gering
# Processing Record 41 of Set 3 | beloyarskiy
# Processing Record 42 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 43 of Set 3 | bozyazi
# Processing Record 44 of Set 3 | chanika
# Processing Record 45 of Set 3 | labrador city
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | krasnoshchekovo
# Processing Record 48 of Set 3 | calama
# Processing Record 49 of Set 3 | nadym
# Processing Record 0 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 4 | colonia
# Processing Record 2 of Set 4 | port saint john's
# Processing Record 3 of Set 4 | palu
# Processing Record 4 of Set 4 | vladimirovac
# Processing Record 5 of Set 4 | lusaka
# Processing Record 6 of Set 4 | raeren
# Processing Record 7 of Set 4 | zhangjiagang
# Processing Record 8 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 9 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 4 | tanki leendert
# City not found. Skipping...
# Processing Record 11 of Set 4 | sokode
# Processing Record 12 of Set 4 | markovo
# Processing Record 13 of Set 4 | stanley
# Processing Record 14 of Set 4 | ust-nera
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | holualoa
# Processing Record 17 of Set 4 | baturaja
# Processing Record 18 of Set 4 | nar'yan-mar
# Processing Record 19 of Set 4 | tofol
# Processing Record 20 of Set 4 | san antonio de pale
# Processing Record 21 of Set 4 | maintirano
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 4 | vila franca do campo
# Processing Record 25 of Set 4 | kilindoni
# Processing Record 26 of Set 4 | las vegas
# Processing Record 27 of Set 4 | north elba
# Processing Record 28 of Set 4 | santiago
# Processing Record 29 of Set 4 | qaqortoq
# Processing Record 30 of Set 4 | bontang
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | kani keli
# Processing Record 33 of Set 4 | puerto baquerizo moreno
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | crane
# Processing Record 36 of Set 4 | kourou
# Processing Record 37 of Set 4 | touros
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | tsiombe
# Processing Record 40 of Set 4 | high river
# Processing Record 41 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 42 of Set 4 | sechura
# Processing Record 43 of Set 4 | vinton
# Processing Record 44 of Set 4 | el galpon
# Processing Record 45 of Set 4 | yandev
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | saurimo
# Processing Record 48 of Set 4 | kayangel
# Processing Record 49 of Set 4 | saint-francois
# Processing Record 0 of Set 5 | cepin
# Processing Record 1 of Set 5 | agar
# Processing Record 2 of Set 5 | el calafate
# Processing Record 3 of Set 5 | bada barabil
# Processing Record 4 of Set 5 | pemangkat
# Processing Record 5 of Set 5 | varna
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | japekrom
# City not found. Skipping...
# Processing Record 8 of Set 5 | gadzhiyevo
# Processing Record 9 of Set 5 | castillos
# Processing Record 10 of Set 5 | port douglas
# Processing Record 11 of Set 5 | happy valley-goose bay
# Processing Record 12 of Set 5 | vung tau
# Processing Record 13 of Set 5 | kidal
# Processing Record 14 of Set 5 | ilhabela
# Processing Record 15 of Set 5 | isafjordur
# Processing Record 16 of Set 5 | sao gabriel da cachoeira
# Processing Record 17 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 5 | anavyssos
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | anadyr
# Processing Record 21 of Set 5 | la paz
# Processing Record 22 of Set 5 | bikenibeu village
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | prince george
# Processing Record 25 of Set 5 | prince rupert
# Processing Record 26 of Set 5 | bereznehuvate
# Processing Record 27 of Set 5 | wailua homesteads
# Processing Record 28 of Set 5 | grand falls-windsor
# Processing Record 29 of Set 5 | lubango
# Processing Record 30 of Set 5 | zheleznogorsk-ilimskiy
# Processing Record 31 of Set 5 | port shepstone
# Processing Record 32 of Set 5 | sierra grande
# Processing Record 33 of Set 5 | praya
# Processing Record 34 of Set 5 | acapulco de juarez
# Processing Record 35 of Set 5 | jabat
# Processing Record 36 of Set 5 | mejit
# Processing Record 37 of Set 5 | poronaysk
# Processing Record 38 of Set 5 | amga
# Processing Record 39 of Set 5 | aasiaat
# Processing Record 40 of Set 5 | bhadarwah
# Processing Record 41 of Set 5 | wanning
# Processing Record 42 of Set 5 | choibalsan
# Processing Record 43 of Set 5 | mount pearl
# Processing Record 44 of Set 5 | baotou
# Processing Record 45 of Set 5 | ust-tsilma
# Processing Record 46 of Set 5 | salahonda
# Processing Record 47 of Set 5 | rundu
# Processing Record 48 of Set 5 | swakopmund
# Processing Record 49 of Set 5 | whitehorse
# Processing Record 0 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 1 of Set 6 | t'aebaek
# Processing Record 2 of Set 6 | mahdia
# Processing Record 3 of Set 6 | rio bueno
# Processing Record 4 of Set 6 | okhotsk
# Processing Record 5 of Set 6 | kapuskasing
# Processing Record 6 of Set 6 | al jawf
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | telimele
# Processing Record 9 of Set 6 | stephenville
# Processing Record 10 of Set 6 | puerto madero
# Processing Record 11 of Set 6 | ta`u
# Processing Record 12 of Set 6 | gorom-gorom
# Processing Record 13 of Set 6 | novodvinsk
# Processing Record 14 of Set 6 | pangody
# Processing Record 15 of Set 6 | romitan shahri
# City not found. Skipping...
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | xilin hot
# Processing Record 18 of Set 6 | atafu village
# Processing Record 19 of Set 6 | mahanje
# Processing Record 20 of Set 6 | ressano garcia
# Processing Record 21 of Set 6 | tazovsky
# Processing Record 22 of Set 6 | salta
# Processing Record 23 of Set 6 | corod
# Processing Record 24 of Set 6 | colorno
# Processing Record 25 of Set 6 | walvis bay
# Processing Record 26 of Set 6 | nikolayevsk-on-amure
# Processing Record 27 of Set 6 | mahajanga
# Processing Record 28 of Set 6 | erenhot
# Processing Record 29 of Set 6 | kirensk
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | san rafael del sur
# Processing Record 32 of Set 6 | bamboo flat
# Processing Record 33 of Set 6 | karachayevsk
# Processing Record 34 of Set 6 | yangjiang
# Processing Record 35 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 36 of Set 6 | shanhaiguan
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | kerikeri
# Processing Record 39 of Set 6 | rancho palos verdes
# Processing Record 40 of Set 6 | port alfred
# Processing Record 41 of Set 6 | hotan
# Processing Record 42 of Set 6 | sebdou
# Processing Record 43 of Set 6 | klaksvik
# Processing Record 44 of Set 6 | zouerate
# Processing Record 45 of Set 6 | quibdo
# Processing Record 46 of Set 6 | minggang
# Processing Record 47 of Set 6 | santaluz
# Processing Record 48 of Set 6 | island harbour
# Processing Record 49 of Set 6 | quang ngai
# Processing Record 0 of Set 7 | kuta
# Processing Record 1 of Set 7 | paita
# Processing Record 2 of Set 7 | saint-philippe
# Processing Record 3 of Set 7 | dakhla
# Processing Record 4 of Set 7 | buka
# Processing Record 5 of Set 7 | madalena
# Processing Record 6 of Set 7 | watertown
# Processing Record 7 of Set 7 | masterton
# Processing Record 8 of Set 7 | iaciara
# Processing Record 9 of Set 7 | lihue
# Processing Record 10 of Set 7 | taltal
# Processing Record 11 of Set 7 | afif
# Processing Record 12 of Set 7 | callao
# Processing Record 13 of Set 7 | malabar
# Processing Record 14 of Set 7 | muynoq
# Processing Record 15 of Set 7 | bokani
# Processing Record 16 of Set 7 | bodo
# Processing Record 17 of Set 7 | bubaque
# Processing Record 18 of Set 7 | severo-yeniseyskiy
# Processing Record 19 of Set 7 | panama city beach
# Processing Record 20 of Set 7 | xinshi
# Processing Record 21 of Set 7 | vadso
# Processing Record 22 of Set 7 | carnarvon
# Processing Record 23 of Set 7 | muang xay
# Processing Record 24 of Set 7 | laascaanood
# Processing Record 25 of Set 7 | ubiaja
# Processing Record 26 of Set 7 | toksovo
# Processing Record 27 of Set 7 | el abiodh sidi cheikh
# Processing Record 28 of Set 7 | santa helena de goias
# Processing Record 29 of Set 7 | moab
# Processing Record 30 of Set 7 | thal
# Processing Record 31 of Set 7 | san patricio
# Processing Record 32 of Set 7 | chongjin
# Processing Record 33 of Set 7 | natal
# Processing Record 34 of Set 7 | farshut
# Processing Record 35 of Set 7 | magong
# Processing Record 36 of Set 7 | tongliao
# Processing Record 37 of Set 7 | shenjiamen
# Processing Record 38 of Set 7 | al ghayzah
# Processing Record 39 of Set 7 | san andres
# Processing Record 40 of Set 7 | vilyuchinsk
# Processing Record 41 of Set 7 | al kharijah
# Processing Record 42 of Set 7 | el bolson
# Processing Record 43 of Set 7 | ayod
# City not found. Skipping...
# Processing Record 44 of Set 7 | maumere
# Processing Record 45 of Set 7 | carutapera
# Processing Record 46 of Set 7 | charters towers
# Processing Record 47 of Set 7 | chinchilla
# Processing Record 48 of Set 7 | kununurra
# Processing Record 49 of Set 7 | dryden
# Processing Record 0 of Set 8 | rongelap
# Processing Record 1 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 2 of Set 8 | talcahuano
# Processing Record 3 of Set 8 | fort mcmurray
# Processing Record 4 of Set 8 | maputo
# Processing Record 5 of Set 8 | saldanha
# Processing Record 6 of Set 8 | praia da vitoria
# Processing Record 7 of Set 8 | claiborne
# Processing Record 8 of Set 8 | oualidia
# City not found. Skipping...
# Processing Record 9 of Set 8 | chonchi
# Processing Record 10 of Set 8 | micheweni
# Processing Record 11 of Set 8 | bandiagara
# Processing Record 12 of Set 8 | tyup
# Processing Record 13 of Set 8 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | taman rajawali
# City not found. Skipping...
# Processing Record 15 of Set 8 | harper
# Processing Record 16 of Set 8 | kailua-kona
# Processing Record 17 of Set 8 | kattivakkam
# Processing Record 18 of Set 8 | goz beida
# Processing Record 19 of Set 8 | san luis
# Processing Record 20 of Set 8 | tarnogskiy gorodok
# Processing Record 21 of Set 8 | mhamid
# Processing Record 22 of Set 8 | sinop
# Processing Record 23 of Set 8 | bosobolo
# Processing Record 24 of Set 8 | chibuto
# Processing Record 25 of Set 8 | trincomalee
# Processing Record 26 of Set 8 | ponnani
# Processing Record 27 of Set 8 | saintes
# Processing Record 28 of Set 8 | cauquenes
# Processing Record 29 of Set 8 | mansa
# Processing Record 30 of Set 8 | cartagena
# Processing Record 31 of Set 8 | navia
# Processing Record 32 of Set 8 | shimoda
# Processing Record 33 of Set 8 | dunbar
# Processing Record 34 of Set 8 | westport
# Processing Record 35 of Set 8 | upata
# Processing Record 36 of Set 8 | adilcevaz
# Processing Record 37 of Set 8 | griffith
# Processing Record 38 of Set 8 | nsanje
# Processing Record 39 of Set 8 | christchurch
# Processing Record 40 of Set 8 | plouzane
# Processing Record 41 of Set 8 | novyy urgal
# Processing Record 42 of Set 8 | crotone
# Processing Record 43 of Set 8 | ribeiropolis
# Processing Record 44 of Set 8 | gulbene
# Processing Record 45 of Set 8 | north platte
# Processing Record 46 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 8 | gary
# Processing Record 48 of Set 8 | minas de marcona
# Processing Record 49 of Set 8 | tres arroyos
# Processing Record 0 of Set 9 | vila velha
# Processing Record 1 of Set 9 | kaa-khem
# Processing Record 2 of Set 9 | hastings
# Processing Record 3 of Set 9 | north battleford
# Processing Record 4 of Set 9 | alhama de murcia
# Processing Record 5 of Set 9 | prieska
# Processing Record 6 of Set 9 | puerto aysen
# Processing Record 7 of Set 9 | arraial do cabo
# Processing Record 8 of Set 9 | san luis de la loma
# Processing Record 9 of Set 9 | abra pampa
# Processing Record 10 of Set 9 | bologoye
# Processing Record 11 of Set 9 | santa elena de uairen
# Processing Record 12 of Set 9 | kamina
# Processing Record 13 of Set 9 | mazagao
# Processing Record 14 of Set 9 | sungai penuh
# Processing Record 15 of Set 9 | fallon
# Processing Record 16 of Set 9 | kokoda
# Processing Record 17 of Set 9 | wenchang
# Processing Record 18 of Set 9 | jolo
# Processing Record 19 of Set 9 | imamoglu
# Processing Record 20 of Set 9 | cole harbour
# Processing Record 21 of Set 9 | canatlan
# Processing Record 22 of Set 9 | cururupu
# Processing Record 23 of Set 9 | pandan
# Processing Record 24 of Set 9 | muramvya
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | mogadishu
# Processing Record 27 of Set 9 | hacienda huancane
# Processing Record 28 of Set 9 | portland
# Processing Record 29 of Set 9 | kiunga
# Processing Record 30 of Set 9 | farasan
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | pitkyaranta
# Processing Record 33 of Set 9 | brookings
# Processing Record 34 of Set 9 | qamdo
# Processing Record 35 of Set 9 | shalya
# Processing Record 36 of Set 9 | taro
# Processing Record 37 of Set 9 | sarkand
# Processing Record 38 of Set 9 | viedma
# Processing Record 39 of Set 9 | edd
# Processing Record 40 of Set 9 | bull savanna
# Processing Record 41 of Set 9 | morden
# Processing Record 42 of Set 9 | daru
# Processing Record 43 of Set 9 | lugu
# Processing Record 44 of Set 9 | tommot
# Processing Record 45 of Set 9 | rudnya
# Processing Record 46 of Set 9 | kerouane
# Processing Record 47 of Set 9 | port moresby
# Processing Record 48 of Set 9 | veraval
# Processing Record 49 of Set 9 | xunchang
# Processing Record 0 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 1 of Set 10 | calp
# Processing Record 2 of Set 10 | guiberoua
# Processing Record 3 of Set 10 | great falls
# Processing Record 4 of Set 10 | tevragh zeina
# City not found. Skipping...
# Processing Record 5 of Set 10 | tindouf
# Processing Record 6 of Set 10 | acarau
# Processing Record 7 of Set 10 | tesistan
# Processing Record 8 of Set 10 | timbuktu
# Processing Record 9 of Set 10 | quibala
# Processing Record 10 of Set 10 | pimentel
# Processing Record 11 of Set 10 | darnah
# Processing Record 12 of Set 10 | shevchenko
# Processing Record 13 of Set 10 | wabag
# Processing Record 14 of Set 10 | yuzhno-kurilsk
# Processing Record 15 of Set 10 | prado
# Processing Record 16 of Set 10 | crockett
# Processing Record 17 of Set 10 | port sudan
# Processing Record 18 of Set 10 | palmer
# Processing Record 19 of Set 10 | kittila
# Processing Record 20 of Set 10 | aldama
# Processing Record 21 of Set 10 | liwale
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | jinghong
# Processing Record 24 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 10 | syriam
# Processing Record 26 of Set 10 | lai
# Processing Record 27 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 10 | alaghsas
# Processing Record 29 of Set 10 | petropavl
# Processing Record 30 of Set 10 | barentu
# Processing Record 31 of Set 10 | pisco
# Processing Record 32 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | mitu
# Processing Record 34 of Set 10 | rabo de peixe
# Processing Record 35 of Set 10 | jayapura
# Processing Record 36 of Set 10 | piacabucu
# Processing Record 37 of Set 10 | esbjerg
# Processing Record 38 of Set 10 | am timan
# Processing Record 39 of Set 10 | hanting
# Processing Record 40 of Set 10 | barra de santo antonio
# Processing Record 41 of Set 10 | kavalerovo
# Processing Record 42 of Set 10 | mabaruma
# Processing Record 43 of Set 10 | waddan
# Processing Record 44 of Set 10 | port lincoln
# Processing Record 45 of Set 10 | kangding
# Processing Record 46 of Set 10 | orchard homes
# Processing Record 47 of Set 10 | shiyan
# Processing Record 48 of Set 10 | papao
# Processing Record 49 of Set 10 | zlate moravce
# Processing Record 0 of Set 11 | solikamsk
# Processing Record 1 of Set 11 | khovd
# Processing Record 2 of Set 11 | mount gambier
# Processing Record 3 of Set 11 | aripuana
# Processing Record 4 of Set 11 | cuito
# Processing Record 5 of Set 11 | dwarka
# Processing Record 6 of Set 11 | mossel bay
# Processing Record 7 of Set 11 | nemuro
# Processing Record 8 of Set 11 | basco
# Processing Record 9 of Set 11 | lahad datu
# Processing Record 10 of Set 11 | mata-utu
# Processing Record 11 of Set 11 | puerto leguizamo
# Processing Record 12 of Set 11 | saltillo
# Processing Record 13 of Set 11 | muroran
# Processing Record 14 of Set 11 | cravinhos
# Processing Record 15 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 16 of Set 11 | barvinkove
# Processing Record 17 of Set 11 | sarangani
# Processing Record 18 of Set 11 | point pedro
# Processing Record 19 of Set 11 | forster
# Processing Record 20 of Set 11 | balikpapan
# Processing Record 21 of Set 11 | novyye burasy
# Processing Record 22 of Set 11 | springwood
# Processing Record 23 of Set 11 | sitia
# Processing Record 24 of Set 11 | qapqal
# City not found. Skipping...
# Processing Record 25 of Set 11 | shama junction
# Processing Record 26 of Set 11 | uzgen
# Processing Record 27 of Set 11 | saudarkrokur
# Processing Record 28 of Set 11 | hirara
# Processing Record 29 of Set 11 | pljevlja
# Processing Record 30 of Set 11 | sanming
# Processing Record 31 of Set 11 | howard springs
# Processing Record 32 of Set 11 | pesqueira
# Processing Record 33 of Set 11 | fortuna
# Processing Record 34 of Set 11 | padang
# Processing Record 35 of Set 11 | igarka
# Processing Record 36 of Set 11 | garissa
# Processing Record 37 of Set 11 | half moon bay
# Processing Record 38 of Set 11 | zimovniki
# Processing Record 39 of Set 11 | pitomaca
# Processing Record 40 of Set 11 | rio gallegos
# Processing Record 41 of Set 11 | tulsipur
# Processing Record 42 of Set 11 | faya-largeau
# Processing Record 43 of Set 11 | ariquemes
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | famagusta
# Processing Record 46 of Set 11 | capao bonito
# Processing Record 47 of Set 11 | torghay
# Processing Record 48 of Set 11 | sonqor
# Processing Record 49 of Set 11 | rio grande
# Processing Record 0 of Set 12 | woods creek
# Processing Record 1 of Set 12 | trinidad
# Processing Record 2 of Set 12 | tshikapa
# Processing Record 3 of Set 12 | broken hill
# Processing Record 4 of Set 12 | mirny
# Processing Record 5 of Set 12 | ardakan
# Processing Record 6 of Set 12 | visby
# Processing Record 7 of Set 12 | emerald
# Processing Record 8 of Set 12 | fisterra
# Processing Record 9 of Set 12 | egilsstadir
# Processing Record 10 of Set 12 | angaur state
# Processing Record 11 of Set 12 | impfondo
# Processing Record 12 of Set 12 | pingdu
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | fada
# Processing Record 15 of Set 12 | sisimiut
# Processing Record 16 of Set 12 | geraldton
# Processing Record 17 of Set 12 | say
# Processing Record 18 of Set 12 | kralendijk
# Processing Record 19 of Set 12 | forde
# Processing Record 20 of Set 12 | chapaev
# Processing Record 21 of Set 12 | rio preto da eva
# Processing Record 22 of Set 12 | adre
# Processing Record 23 of Set 12 | kwang binh
# Processing Record 24 of Set 12 | yeppoon
# Processing Record 25 of Set 12 | ca mau
# Processing Record 26 of Set 12 | bayganin
# Processing Record 27 of Set 12 | cameta
# Processing Record 28 of Set 12 | altamira
# Processing Record 29 of Set 12 | kamennomostskoye
# Processing Record 30 of Set 12 | mandalgovi
# Processing Record 31 of Set 12 | ketchikan
# Processing Record 32 of Set 12 | lhokseumawe
# Processing Record 33 of Set 12 | marquette
# Processing Record 34 of Set 12 | ambon
# Processing Record 35 of Set 12 | pariaman
# Processing Record 36 of Set 12 | la ligua
# Processing Record 37 of Set 12 | nieuw amsterdam
# Processing Record 38 of Set 12 | lira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | farsund
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lanzhou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | colorado
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | nuevo laredo
# Processing Record 24 of Set 1 | guiratinga
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | dukat
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | senneterre
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | zangakatun
# Processing Record 34 of Set 1 | saint-louis
# Processing Record 35 of Set 1 | midwest city
# Processing Record 36 of Set 1 | grimmen
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | stornoway
# Processing Record 39 of Set 1 | naberera
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | drochia
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | tomatlan
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | collierville
# Processing Record 50 of Set 1 | kapaa
# Processing Record 0 of Set 2 | mogadishu
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | tsalka
# Processing Record 3 of Set 2 | dalby
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | businga
# Processing Record 8 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 2 | lasa
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | ust-kulom
# Processing Record 13 of Set 2 | udachnyy
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | airai
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | banda
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | mendi
# Processing Record 28 of Set 2 | cobija
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | deer lake
# Processing Record 31 of Set 2 | nalut
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | dudinka
# Processing Record 34 of Set 2 | zamberk
# Processing Record 35 of Set 2 | jaguariaiva
# Processing Record 36 of Set 2 | aberdeen
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | kedrovyy
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | qostanay
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | darnah
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | rafaela
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | solnechnyy
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 3 | alba
# Processing Record 1 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 2 of Set 3 | arman
# Processing Record 3 of Set 3 | ugoofaaru
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | zhangye
# Processing Record 7 of Set 3 | shenjiamen
# Processing Record 8 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 3 | itarema
# Processing Record 10 of Set 3 | trincomalee
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | heihe
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | siavonga
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | nova olimpia
# Processing Record 18 of Set 3 | palencia
# Processing Record 19 of Set 3 | inhambane
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | calabozo
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | yidu
# Processing Record 28 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 3 | cedar city
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | lichuan
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | novorzhev
# Processing Record 39 of Set 3 | muncar
# Processing Record 40 of Set 3 | jashpurnagar
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | kulykivka
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | bocana de paiwas
# Processing Record 45 of Set 3 | el alto
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | punta arenas
# Processing Record 48 of Set 3 | bay city
# Processing Record 49 of Set 3 | baruun-urt
# Processing Record 0 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | corowa
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | ocos
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | brenham
# Processing Record 8 of Set 4 | peniche
# Processing Record 9 of Set 4 | tawang
# Processing Record 10 of Set 4 | havelock
# Processing Record 11 of Set 4 | novobelokatay
# Processing Record 12 of Set 4 | puerto del rosario
# Processing Record 13 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | rindal
# Processing Record 16 of Set 4 | roseburg
# Processing Record 17 of Set 4 | kaeo
# Processing Record 18 of Set 4 | biak
# Processing Record 19 of Set 4 | kahului
# Processing Record 20 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | sabang
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | corn island
# Processing Record 26 of Set 4 | innisfail
# Processing Record 27 of Set 4 | almaznyy
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | burica
# City not found. Skipping...
# Processing Record 30 of Set 4 | kokopo
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | sao miguel do araguaia
# Processing Record 33 of Set 4 | belmonte
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | ambilobe
# Processing Record 36 of Set 4 | aripuana
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 4 | lesnoy
# Processing Record 40 of Set 4 | evensk
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | la ronge
# Processing Record 43 of Set 4 | danielskuil
# Processing Record 44 of Set 4 | chunhuhub
# Processing Record 45 of Set 4 | avera
# Processing Record 46 of Set 4 | ouallam
# Processing Record 47 of Set 4 | challapata
# Processing Record 48 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 0 of Set 5 | neepawa
# Processing Record 1 of Set 5 | freetown
# Processing Record 2 of Set 5 | nome
# Processing Record 3 of Set 5 | hovd
# Processing Record 4 of Set 5 | ugra
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | sembakung
# Processing Record 7 of Set 5 | shakawe
# Processing Record 8 of Set 5 | upington
# Processing Record 9 of Set 5 | gwanda
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | grand gaube
# Processing Record 12 of Set 5 | cacahuatepec
# Processing Record 13 of Set 5 | paita
# Processing Record 14 of Set 5 | bumba
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | kosa
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | cabra
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | buala
# Processing Record 22 of Set 5 | asau
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | pevek
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | zyryanka
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | valparaiso
# Processing Record 30 of Set 5 | baykit
# Processing Record 31 of Set 5 | port moresby
# Processing Record 32 of Set 5 | meulaboh
# Processing Record 33 of Set 5 | nakamura
# Processing Record 34 of Set 5 | simao
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | kodinsk
# Processing Record 38 of Set 5 | luderitz
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | glasgow
# Processing Record 41 of Set 5 | ladario
# Processing Record 42 of Set 5 | sao teotonio
# Processing Record 43 of Set 5 | puri
# Processing Record 44 of Set 5 | yumbe
# Processing Record 45 of Set 5 | pangkalanbuun
# Processing Record 46 of Set 5 | hay river
# Processing Record 47 of Set 5 | verkhniye achaluki
# Processing Record 48 of Set 5 | terrace bay
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 6 | ust-koksa
# Processing Record 1 of Set 6 | sorong
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | lensk
# Processing Record 6 of Set 6 | carrollton
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | makokou
# Processing Record 9 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 6 | llata
# Processing Record 11 of Set 6 | neiafu
# Processing Record 12 of Set 6 | moroni
# Processing Record 13 of Set 6 | cap malheureux
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | rawson
# Processing Record 16 of Set 6 | tikaitnagar
# Processing Record 17 of Set 6 | sembe
# Processing Record 18 of Set 6 | aksu
# Processing Record 19 of Set 6 | russkaya polyana
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | beya
# Processing Record 23 of Set 6 | goba
# Processing Record 24 of Set 6 | ordzhonikidze
# Processing Record 25 of Set 6 | high rock
# Processing Record 26 of Set 6 | floro
# Processing Record 27 of Set 6 | balabac
# Processing Record 28 of Set 6 | bintulu
# Processing Record 29 of Set 6 | tchaourou
# Processing Record 30 of Set 6 | zhongshan
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | quatre cocos
# Processing Record 33 of Set 6 | prieska
# Processing Record 34 of Set 6 | pathanamthitta
# Processing Record 35 of Set 6 | comodoro rivadavia
# Processing Record 36 of Set 6 | sungaipenuh
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | camacha
# Processing Record 39 of Set 6 | thompson
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | swanton
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | chapais
# Processing Record 45 of Set 6 | chengde
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | berdigestyakh
# Processing Record 48 of Set 6 | coquimbo
# Processing Record 49 of Set 6 | samana
# Processing Record 0 of Set 7 | anchorage
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | ola
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | jiuquan
# Processing Record 8 of Set 7 | tuatapere
# Processing Record 9 of Set 7 | kloulklubed
# Processing Record 10 of Set 7 | ust-maya
# Processing Record 11 of Set 7 | san juan
# Processing Record 12 of Set 7 | whitianga
# Processing Record 13 of Set 7 | praia
# Processing Record 14 of Set 7 | okitipupa
# Processing Record 15 of Set 7 | monmouth
# Processing Record 16 of Set 7 | san andres
# Processing Record 17 of Set 7 | lyngseidet
# Processing Record 18 of Set 7 | dunmore town
# Processing Record 19 of Set 7 | galegos
# Processing Record 20 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 7 | kamen-rybolov
# Processing Record 22 of Set 7 | dabat
# Processing Record 23 of Set 7 | camopi
# Processing Record 24 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 7 | jalu
# Processing Record 26 of Set 7 | eyl
# Processing Record 27 of Set 7 | valdivia
# Processing Record 28 of Set 7 | teguldet
# Processing Record 29 of Set 7 | aquiraz
# Processing Record 30 of Set 7 | ulaangom
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | vrakhnaiika
# City not found. Skipping...
# Processing Record 33 of Set 7 | alice springs
# Processing Record 34 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 7 | koriyama
# Processing Record 36 of Set 7 | kingman
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | la romana
# Processing Record 39 of Set 7 | daru
# Processing Record 40 of Set 7 | boden
# Processing Record 41 of Set 7 | carroll
# Processing Record 42 of Set 7 | ust-kuyga
# Processing Record 43 of Set 7 | bucerias
# Processing Record 44 of Set 7 | tandil
# Processing Record 45 of Set 7 | horsham
# Processing Record 46 of Set 7 | vao
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | harwich
# Processing Record 0 of Set 8 | sambava
# Processing Record 1 of Set 8 | yarada
# Processing Record 2 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | kokkola
# Processing Record 5 of Set 8 | leningradskiy
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 8 | chegdomyn
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | viseu
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | bafoulabe
# Processing Record 14 of Set 8 | swan river
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | juruti
# Processing Record 17 of Set 8 | kailua
# Processing Record 18 of Set 8 | verkh-suetka
# Processing Record 19 of Set 8 | dunedin
# Processing Record 20 of Set 8 | mount isa
# Processing Record 21 of Set 8 | mahina
# Processing Record 22 of Set 8 | kamloops
# Processing Record 23 of Set 8 | santa rosalia
# Processing Record 24 of Set 8 | nerchinskiy zavod
# Processing Record 25 of Set 8 | torrington
# Processing Record 26 of Set 8 | krutikha
# Processing Record 27 of Set 8 | bonavista
# Processing Record 28 of Set 8 | zaysan
# Processing Record 29 of Set 8 | mana
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | mandera
# Processing Record 32 of Set 8 | numan
# Processing Record 33 of Set 8 | pingliang
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | honiara
# Processing Record 39 of Set 8 | pemba
# Processing Record 40 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | lerik
# Processing Record 46 of Set 8 | quelimane
# Processing Record 47 of Set 8 | katyuzhanka
# Processing Record 48 of Set 8 | narwar
# Processing Record 49 of Set 8 | port hardy
# Processing Record 0 of Set 9 | sol-iletsk
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | srednekolymsk
# Processing Record 4 of Set 9 | homer
# Processing Record 5 of Set 9 | livingston
# Processing Record 6 of Set 9 | lima
# Processing Record 7 of Set 9 | christchurch
# Processing Record 8 of Set 9 | beitbridge
# Processing Record 9 of Set 9 | kortkeros
# Processing Record 10 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 9 | port hedland
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | dicabisagan
# Processing Record 14 of Set 9 | smithers
# Processing Record 15 of Set 9 | peleduy
# Processing Record 16 of Set 9 | yulara
# Processing Record 17 of Set 9 | roebourne
# Processing Record 18 of Set 9 | mariinskiy posad
# Processing Record 19 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | ribeira grande
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | saint-francois
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | bogande
# Processing Record 31 of Set 9 | quesnel
# Processing Record 32 of Set 9 | usman
# Processing Record 33 of Set 9 | aykhal
# Processing Record 34 of Set 9 | carlyle
# Processing Record 35 of Set 9 | kayerkan
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | seoul
# Processing Record 40 of Set 9 | woodward
# Processing Record 41 of Set 9 | georgiyevskoye
# Processing Record 42 of Set 9 | mayo
# Processing Record 43 of Set 9 | kysyl-syr
# Processing Record 44 of Set 9 | tashara
# Processing Record 45 of Set 9 | acajutla
# Processing Record 46 of Set 9 | capoterra
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | maniitsoq
# Processing Record 0 of Set 10 | kalemie
# Processing Record 1 of Set 10 | tagusao
# Processing Record 2 of Set 10 | mao
# Processing Record 3 of Set 10 | mahibadhoo
# Processing Record 4 of Set 10 | cabo san lucas
# Processing Record 5 of Set 10 | panuco
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | fayaoue
# Processing Record 8 of Set 10 | stolac
# Processing Record 9 of Set 10 | gamboma
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | carutapera
# Processing Record 12 of Set 10 | port-de-bouc
# Processing Record 13 of Set 10 | nanortalik
# Processing Record 14 of Set 10 | dzaoudzi
# Processing Record 15 of Set 10 | aktau
# Processing Record 16 of Set 10 | lorengau
# Processing Record 17 of Set 10 | pachino
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | denpasar
# Processing Record 20 of Set 10 | ipixuna
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | lakki marwat
# Processing Record 24 of Set 10 | veinticinco de mayo
# Processing Record 25 of Set 10 | avdon
# Processing Record 26 of Set 10 | katobu
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | merauke
# Processing Record 29 of Set 10 | yangliuqing
# Processing Record 30 of Set 10 | tieling
# Processing Record 31 of Set 10 | togur
# Processing Record 32 of Set 10 | thinadhoo
# Processing Record 33 of Set 10 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 34 of Set 10 | terra santa
# Processing Record 35 of Set 10 | colares
# Processing Record 36 of Set 10 | havoysund
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | samandag
# Processing Record 40 of Set 10 | san joaquin
# Processing Record 41 of Set 10 | treinta y tres
# Processing Record 42 of Set 10 | nazareno
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | yaan
# Processing Record 45 of Set 10 | ixtapa
# Processing Record 46 of Set 10 | dong hoi
# Processing Record 47 of Set 10 | harindanga
# Processing Record 48 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 10 | pontypool
# Processing Record 0 of Set 11 | ulladulla
# Processing Record 1 of Set 11 | la paz
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | barroso
# Processing Record 4 of Set 11 | vryburg
# Processing Record 5 of Set 11 | beira
# Processing Record 6 of Set 11 | the valley
# Processing Record 7 of Set 11 | narsaq
# Processing Record 8 of Set 11 | juegang
# Processing Record 9 of Set 11 | verkhniy avzyan
# Processing Record 10 of Set 11 | berdyuzhye
# City not found. Skipping...
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | tautira
# Processing Record 14 of Set 11 | singkang
# Processing Record 15 of Set 11 | taitung
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | chifeng
# Processing Record 19 of Set 11 | caiaponia
# Processing Record 20 of Set 11 | salto
# Processing Record 21 of Set 11 | praya
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | abu zabad
# Processing Record 24 of Set 11 | kushima
# Processing Record 25 of Set 11 | beaune
# Processing Record 26 of Set 11 | egvekinot
# Processing Record 27 of Set 11 | greenville
# Processing Record 28 of Set 11 | ust-ordynskiy
# Processing Record 29 of Set 11 | tranas
# Processing Record 30 of Set 11 | pleasanton
# Processing Record 31 of Set 11 | beringovskiy
# Processing Record 32 of Set 11 | newcastleton
# Processing Record 33 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 11 | hirado
# Processing Record 35 of Set 11 | brokopondo
# Processing Record 36 of Set 11 | batagay
# Processing Record 37 of Set 11 | laurel
# Processing Record 38 of Set 11 | statesville
# Processing Record 39 of Set 11 | tikrit
# Processing Record 40 of Set 11 | iisalmi
# Processing Record 41 of Set 11 | lahij
# Processing Record 42 of Set 11 | derzhavinsk
# Processing Record 43 of Set 11 | kyren
# Processing Record 44 of Set 11 | kapit
# Processing Record 45 of Set 11 | altay
# Processing Record 46 of Set 11 | waseca
# Processing Record 47 of Set 11 | nantucket
# Processing Record 48 of Set 11 | cadillac
# Processing Record 49 of Set 11 | sfantu gheorghe
# Processing Record 0 of Set 12 | kundiawa
# Processing Record 1 of Set 12 | gornopravdinsk
# Processing Record 2 of Set 12 | bhandara
# Processing Record 3 of Set 12 | wadi musa
# Processing Record 4 of Set 12 | charters towers
# Processing Record 5 of Set 12 | ustka
# Processing Record 6 of Set 12 | sawakin
# Processing Record 7 of Set 12 | severo-kurilsk
# Processing Record 8 of Set 12 | rameswaram
# Processing Record 9 of Set 12 | guerrero negro
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | antofagasta
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | bauta
# Processing Record 14 of Set 12 | nsanje
# Processing Record 15 of Set 12 | xuchang
# Processing Record 16 of Set 12 | todos santos
# Processing Record 17 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 12 | bataipora
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | yaring
# Processing Record 24 of Set 12 | isiro
# Processing Record 25 of Set 12 | chivilcoy
# Processing Record 26 of Set 12 | mandalgovi
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | novocheremshansk
# Processing Record 29 of Set 12 | emirdag
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | ryomgard
# Processing Record 33 of Set 12 | khudumelapye
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | gifhorn
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | kalabo
# Processing Record 40 of Set 12 | arcata
# Processing Record 41 of Set 12 | lemoore
# Processing Record 42 of Set 12 | norfolk
# Processing Record 43 of Set 12 | juba
# Processing Record 44 of Set 12 | pali
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | bulgan
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | saryg-sep
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | changli
# Processing Record 7 of Set 13 | choma
# Processing Record 8 of Set 13 | tena
# Processing Record 9 of Set 13 | ilhabela
# Processing Record 10 of Set 13 | redmond
# Processing Record 11 of Set 13 | wyndham
# Processing Record 12 of Set 13 | nhulunbuy
# Processing Record 13 of Set 13 | sangamner
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | staryy nadym
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | tatarsk
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     paranaiba -19.6772  -51.1908     28.39        50          53
# 1      afaahiti -17.7500 -149.2833     28.93        81          53
# 2      enewetak  11.3474  162.3373     27.11        70           7
# 3  puerto ayora  -0.7393  -90.3518     25.86        93         100
# 4        saipan  15.1355  145.7010     28.39        83          40
#
#    Wind Speed Country        Date
# 0        2.19      BR  1704671844
# 1        4.67      PF  1704671845
# 2        9.47      MH  1704671846
# 3        1.79      EC  1704671846
# 4        7.20      MP  1704671847

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           paranaiba -19.6772  -51.1908     28.39        50          53
# 1            afaahiti -17.7500 -149.2833     28.93        81          53
# 2            enewetak  11.3474  162.3373     27.11        70           7
# 3        puerto ayora  -0.7393  -90.3518     25.86        93         100
# 4              saipan  15.1355  145.7010     28.39        83          40
#
#          Wind Speed Country        Date
# City_ID
# 0              2.19      BR  1704671844
# 1              4.67      PF  1704671845
# 2              9.47      MH  1704671846
# 3              1.79      EC  1704671846
# 4              7.20      MP  1704671847

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values, edgecolors = "black")

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("../output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Humidity"].astype("float")
plt.scatter(x_values,y_values, edgecolors = "black")

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Humidity (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("../output/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values, edgecolors = "black")

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Cloudiness (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("../output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values, edgecolors = "black")

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Wind Speed (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("../output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress_line(x_values, y_values):
        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        line_function = f"y = {slope}x + {intercept}"
        return line_function

def regress_line(x_values, y_values):
        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        return regress_values

def r_value(x_values, y_values):
        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        return rvalue

# %%
# test your functions to show that it works

# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values, edgecolors = "black")

#Use functions to find values
line_function = lin_regress_line(x_values, y_values)
regress_values = regress_line(x_values, y_values)
rvalue = r_value(x_values, y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_function,(6,10),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Incorporate the other graph properties

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')


# Show plot
plt.show()
# Out:
# The r-value is: 0.5697364952800517

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                        enewetak  11.3474  162.3373     27.11        70
# 4                          saipan  15.1355  145.7010     28.39        83
# 5        petropavlovsk-kamchatsky  53.0452  158.6483    -15.86        78
# 6                           sitka  57.0531 -135.3300      3.94        56
# 7                        sinabang   2.4803   96.3801     27.07        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 7        9.47      MH  1704671846
# 4                40        7.20      MP  1704671847
# 5                20        5.36      RU  1704671847
# 6               100        8.23      US  1704671848
# 7                90        1.04      ID  1704671849

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           paranaiba -19.6772  -51.1908     28.39        50          53
# 1            afaahiti -17.7500 -149.2833     28.93        81          53
# 3        puerto ayora  -0.7393  -90.3518     25.86        93         100
# 8             ushuaia -54.8000  -68.3000      9.81        53          40
# 10          adamstown -25.0660 -130.1015     22.61        75         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.19      BR  1704671844
# 1              4.67      PF  1704671845
# 3              1.79      EC  1704671846
# 8              7.72      AR  1704671849
# 10             6.44      PN  1704671851

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Run linear regression
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values)

#labels
plt.xlabel('Latitude')
plt.ylabel('Max Temp)')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,-10),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7528658851728833

# %%
# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values)

#labels
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.3088300095539568

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# The Northern Hemisphere dataset shows a decrease of Max Temp as the Latitude increases. The values correlate quite strongly with a pretty high r-value and it being quite clustered and then being slightly more spread as you get to larger latitudes. The points are also quite linear with the values decreasing at a steady rate alongside latitude being increased.
#
# The Southern Hemisphere dataset shows an increase of Max Temp as the Latitude increases. The values dont correlate quite as strongly with it being more spread, a smaller r-value and slightly more tight as you get to larger latitudes. The points are slightly linear with the values decreasing at a steady rate alongside latitude being increased.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Build scatter plot for latitude vs. Humidity
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Humidity"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,10),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.18556493620352607

# %%
# Build scatter plot for latitude vs. Humidity
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Humidity"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1192609895743718

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# The Northern Hemisphere dataset shows an increase of humidity as the Latitude increases. The values do not have much correlation with a low r-value and it being slightly more clustered as you get to larger latitudes. The points are not quite linear with the humidity values only showing a slight increase with the latitude.
#
# The Southern Hemisphere dataset shows an increase of humidity as the Latitude increases. The values do not have much correlation with a low r-value and it being slightly more clustered as you get to larger latitudes. The points are not quite linear with the humidity values only showing a slight increase with the latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for latitude vs. Cloudiness
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,22),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.06340778466316468

# %%
# Build scatter plot for latitude vs. Cloudiness
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,40),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04697934523503627

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# The Northern Hemisphere dataset shows an increase of Cloudiness as the Latitude increases. The values do not have any correlation with a low r-value and having heavy clusters. The points have no linearity.
#
# The Southern Hemisphere dataset shows an increase of Cloudiness as the Latitude increases. The values do not have any correlation with a low r-value and having heavy clusters. The points have no linearity.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Build scatter plot for latitude vs. Wind Speed
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,13),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0019653995308259605

# %%
# Build scatter plot for latitude vs. Wind Speed
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#Run Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-15,11),fontsize=10,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.12000789663804945

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# The Northern Hemisphere dataset shows a very slight increase of Wind Speed as the Latitude increases. The values do not have any correlation with a low r-value and having heavy clusters. The points have no linearity.
#
# The Southern Hemisphere dataset shows a slight decrease of Windspeed as the Latitude increases. The values have a correlation with a low r-value, the values get closer as you get to higher latitudes. The points have a slight linearity.
